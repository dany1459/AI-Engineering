# %% [markdown]
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = {"a": np.random.random(500),
        "b": np.random.random(500),
        "c": np.random.random(500),
        "d": np.random.random(500)}
df3 = pd.DataFrame(data)
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   a       500 non-null    float64
#  1   b       500 non-null    float64
#  2   c       500 non-null    float64
#  3   d       500 non-null    float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head(11)
# Out:
#            a         b         c         d
# 0   0.046821  0.681843  0.780913  0.460279
# 1   0.690755  0.586446  0.314883  0.311704
# 2   0.286273  0.308552  0.050457  0.996559
# 3   0.570348  0.831743  0.791723  0.415804
# 4   0.704710  0.475345  0.712232  0.493671
# 5   0.339197  0.277173  0.333957  0.006074
# 6   0.325695  0.573982  0.834024  0.652929
# 7   0.395824  0.690037  0.873262  0.911901
# 8   0.054892  0.709098  0.971442  0.664419
# 9   0.127340  0.247071  0.717790  0.278533
# 10  0.743014  0.663748  0.078352  0.218932

# %% [markdown]
# **Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
plt.scatter(df3['b'], df3['a'], cmap='Blues', s=df3['d']*110)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a histogram of the 'a' column.**

# %%
plt.hist(df3['a'], bins=55)
# Out:
# (array([ 9., 13., 12., 14., 15.,  9., 10., 12., 10.,  8.,  6.,  8.,  4.,
#          9.,  9., 10., 12., 11., 13.,  9., 11., 12.,  6.,  8.,  9., 10.,
#          5.,  6., 12.,  8.,  8.,  7.,  7., 10., 11.,  6., 11., 11., 10.,
#         17.,  9.,  4.,  7.,  8.,  7.,  6.,  6.,  7.,  8.,  6.,  5.,  7.,
#          8.,  9., 15.]),
#  array([0.00243424, 0.02054451, 0.03865478, 0.05676505, 0.07487532,
#         0.09298559, 0.11109586, 0.12920613, 0.1473164 , 0.16542667,
#         0.18353694, 0.20164721, 0.21975748, 0.23786775, 0.25597802,
#         0.27408828, 0.29219855, 0.31030882, 0.32841909, 0.34652936,
#         0.36463963, 0.3827499 , 0.40086017, 0.41897044, 0.43708071,
#         0.45519098, 0.47330125, 0.49141152, 0.50952179, 0.52763206,
#         0.54574233, 0.5638526 , 0.58196287, 0.60007314, 0.61818341,
#         0.63629368, 0.65440395, 0.67251422, 0.69062449, 0.70873476,
#         0.72684503, 0.7449553 , 0.76306557, 0.78117584, 0.79928611,
#         0.81739638, 0.83550665, 0.85361692, 0.87172719, 0.88983746,
#         0.90794773, 0.926058  , 0.94416826, 0.96227853, 0.9803888 ,
#         0.99849907]),
#  <BarContainer object of 55 artists>)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')
plt.hist(df3['a'], bins=33)
# df3['a'].plot.hist(bins=33)
# Out:
# (array([19., 20., 24., 16., 18., 15., 13.,  9., 14., 17., 22., 16., 17.,
#         14., 15., 15.,  8., 18., 14., 13., 16., 11., 18., 26., 11., 13.,
#         11., 11.,  9., 13., 11., 11., 22.]),
#  array([0.00243424, 0.03261802, 0.0628018 , 0.09298559, 0.12316937,
#         0.15335315, 0.18353694, 0.21372072, 0.2439045 , 0.27408828,
#         0.30427207, 0.33445585, 0.36463963, 0.39482342, 0.4250072 ,
#         0.45519098, 0.48537477, 0.51555855, 0.54574233, 0.57592611,
#         0.6061099 , 0.63629368, 0.66647746, 0.69666125, 0.72684503,
#         0.75702881, 0.78721259, 0.81739638, 0.84758016, 0.87776394,
#         0.90794773, 0.93813151, 0.96831529, 0.99849907]),
#  <BarContainer object of 33 artists>)

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a boxplot comparing the a and b columns.**

# %%
df3.boxplot(column=['a', 'b'], figsize=(6,9))
# Out:
# <AxesSubplot:>

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create a kde plot of the 'd' column**

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.kde(bw_method=0.1, linestyle='--')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#DO NOT TOUCH ME

# %% [markdown]
# **Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.iloc[:30].plot.area()
# Out:
# <AxesSubplot:>

# %%
#DO NOT TOUCH ME

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# **Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
df3.iloc[:30].plot.area()
plt.legend(loc=(1, 0.5))

# %%
#DO NOT TOUCH ME

# %% [markdown]
# # Great Job!
