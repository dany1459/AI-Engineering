# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Figures and Axes

# %%
fig = plt.figure()
fig.add_subplot(2, 2, 1) # 2 rows, 2 cols, first element
fig.add_subplot(2, 2, 4) # 2 rows, 2 cols, last element
fig.show()
# Out:
# C:\Users\Igor\AppData\Local\Temp/ipykernel_2476/2495016403.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
fig.add_subplot(2, 2, 2) # 2 rows, 2 cols, second element
fig.add_subplot(2, 2, 3) # 2 rows, 2 cols, third element
fig.show()
# Out:
# C:\Users\Igor\AppData\Local\Temp/ipykernel_2476/3064625632.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xticklabels(['-std2', '-std1', 'mean', 'std1', 'std2'])
# Out:
# [Text(-2, 0, '-std2'),
#  Text(-1, 0, '-std1'),
#  Text(0, 0, 'mean'),
#  Text(1, 0, 'std1'),
#  Text(2, 0, 'std2')]

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.set_xticks([-2, -1, 0, 1, 2])
ax.set_xticklabels(['-std2', '-std1', 'mean', 'std1', 'std2'])
ax.set_yticks([-2, -1, 0, 1, 2])
ax.set_yticklabels(['-y_tick2', '-y_tick1', 'y_tick', 'y_tick1', 'y_tick2'])
# Out:
# [Text(0, -2, '-y_tick2'),
#  Text(0, -1, '-y_tick1'),
#  Text(0, 0, 'y_tick'),
#  Text(0, 1, 'y_tick1'),
#  Text(0, 2, 'y_tick2')]

# %%
plt.scatter(
    np.random.normal(size=10), np.random.normal(size=10)
)

# %%
plt.plot(
    np.arange(-100, 100, 0.01), np.sin(np.arange(-100, 100, 0.01))
)

# %% [markdown]
# You can constrain the x and y axis values with `xlim` and `ylim` methods:

# %%
plt.ylim(-1.5,1.5)
plt.xlim(-5,5)
plt.plot(
    np.arange(-100, 100, 0.01), np.sin(np.arange(-100, 100, 0.01))
)

# %% [markdown]
# If you take a deeper look at the [matplotlib.pyplot.plot documentation](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html) you can see how to tune the various arguments to produce more specific plots:

# %%
plt.xlim(-3,3)
plt.plot(
    np.arange(-5, 6, 0.01), np.sin(np.arange(-5, 6, 0.01)), color='r', marker='o',
    linestyle='--', linewidth=3, markersize=1, markerfacecolor="k"
)
plt.xlabel("X Label")
plt.ylabel("Y Label")
plt.legend(loc="upper right") # no need in this example
plt.title("This is the title")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.hist(
    np.random.normal(size=100)
)
# Out:
# (array([ 1.,  4., 13., 18., 20., 24., 13.,  3.,  3.,  1.]),
#  array([-2.65355866, -2.09891628, -1.5442739 , -0.98963153, -0.43498915,
#          0.11965323,  0.67429561,  1.22893798,  1.78358036,  2.33822274,
#          2.89286511]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Pie
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
plt.pie(
    [0.2, 0.3, 0.5]
)
# Out:
# ([<matplotlib.patches.Wedge at 0x2648aa4cf10>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, ''),
#   Text(-0.64656382751384, 0.8899186574910392, ''),
#   Text(1.0298943251329445e-07, -1.0999999999999954, '')])

# %% [markdown]
# ### Histogram

# %%
pd.Series([0.4, 0.2, 0.3, 0.5]).plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>
