# %%
#jupyter notebook settings not a must but helps
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# helps in defining a model in sequential 
from collections import OrderedDict

import numpy as np
import matplotlib.pyplot as plt
import time

import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

# dealing with images 
from torchvision import datasets, transforms

# %% [markdown]
# # Aux Plotting function

# %%
# https://discuss.pytorch.org/t/view-classify-in-module-helper/30279/6
# for visualising samples, this helps to debug 

def view_classify(img, ps):  # ps is the list of probabilities

    ps = ps.data.numpy().squeeze() # convert to numpy array and remove the first dimension

    fig, (ax1, ax2) = plt.subplots(figsize=(6,9), ncols=2)
    ax1.imshow(img.resize_(1, 28, 28).numpy().squeeze())
    ax1.axis('off')
    ax2.barh(np.arange(10), ps)
    ax2.set_aspect(0.1)
    ax2.set_yticks(np.arange(10))
    ax2.set_yticklabels(np.arange(10))
    ax2.set_title('Class Probability')
    ax2.set_xlim(0, 1.1)

# %% [markdown]
# # Load MNIST

# %%
# compose is like a pipleline, of the steps that we want to perform
# inituition is that transforms.ToTenso() converts the image to numpy then to tensor, PIL can be used to convert image to numpy array
# normalize is to normalize the image to be between 0 and 1
# transforms.Normalize((0.5), (0.5)) --> mean and std
# since data is grey scale we only need to specify the mean and std for the channel
#if we had colored then the function would be as transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,)) ])

# Download the training data

trainset = datasets.MNIST('MNIST_data/', download=True, train=True, transform=transform )

# we don't want to pass all that data once, cause memory lol
# rule of thumb : small batch size = smaller learning rate, bigger batch size = bigger learning rate
# in theory a big batch size makes trainig faster , the updates may to be big and this impacts the model 

trainloader = torch.utils.data.DataLoader(trainset, batch_size=16, shuffle=True)


# Download the test data
testset    = datasets.MNIST('MNIST_data/', download=True, train=False, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=16, shuffle=True) # shuffle is not necessary for test set, since we are not learning from it

# %%
# we can check the balance of the data 
import pandas as pd
pd.Series(trainset.targets.numpy()).value_counts()
# Out:
# 1    6742
# 7    6265
# 3    6131
# 2    5958
# 9    5949
# 0    5923
# 6    5918
# 8    5851
# 4    5842
# 5    5421
# dtype: int64

# %%
pd.Series(testset.targets.numpy()).value_counts()
# Out:
# 1    1135
# 2    1032
# 7    1028
# 3    1010
# 9    1009
# 4     982
# 0     980
# 8     974
# 6     958
# 5     892
# dtype: int64

# %%
# accessing the data
for data,labels in trainloader:
    print(data.size(), labels.size())
# Out:
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# ...
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])
# torch.Size([16, 1, 28, 28]) torch.Size([16])

# %%
dataiter = iter(trainloader)
images, labels = dataiter.next()

# %%
img = images[0]
#plt.imshow(img) #this wont directly work since we have a 3rd dimension of the image

# we can use .squeeze() to remove the dimension of the image
plt.imshow(img.squeeze())

# %% [markdown]
# # Creating model

# %%
class Network(nn.Module):
    # what does nn.Module mean? well we are inheriting in the atrribute of nn.Module and methods of nn.Module
    # we then overwrite the constructor to define the network we want
    def __init__(self):
        super().__init__()
        self.fc1 = nn.Linear(28*28,128)  # input dim is 28x28 = 784 , value of output is defined by us, can be any number
        self.fc2 = nn.Linear(128,64)
        self.fc3 = nn.Linear(64,10) # the 10 has to be the number of classes, we have 10 classes in this case
        
    # Forward pass through the network, in order to ensure the manner in which the data is being passed through the network, returns the output logits
    # relu performs better than sigmoid as it does not make the values smaller going through the network and we may lose information
    def forward (self,x):
        x = x.view(x.shape[0],784)  # flatten the input, can be done here, or in training loop
        x = self.fc1(x)
        x = F.relu(x) # ReLU is a non-linearity function, it is a function that returns the max of the input and 0. 
            # here we are call it via F as it is a torch function, or you can define it in the method as we saw with sigmoid previously
        x = self.fc2(x)
        x = F.relu(x) #activation function decides whether the nueron fires or not, i.e. passing data through the network
        x = self.fc3(x)
        x = F.softmax(x, dim=1) # to get the probability of each class, dim =1 is the dimension we want to apply softmax on
        return x
    
model = Network()


# alternative manner is the sequential manner, your preference, sequential is more compact

# %%
model
# Out:
# Network(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )

# %%
# if we just pass the images as we have load so far we will see a runtime error complaining that the images are not in the correct shape	
# mat1 --> (1, 28, 28) input to the model
# mat2 --> 784 gven by the weights of the first layer

# so we resize the images to the size of the first layer:
# main difference between resize and view is that resize is a function that changes the size of the image perma, view is a function that returns the image and does
# not change the size of the image
# prefer using the view 
# img.resize_(1,784)


# if we apply the model to the image, we get the output of the probabilities of each class, sum = 1
model(img.view(1, 784))
# we take the argmax of the output of the model, this is the predicted class
# Out:
# tensor([[0.1139, 0.1232, 0.1209, 0.1045, 0.0929, 0.0786, 0.0819, 0.0927, 0.0898,
#          0.1017]], grad_fn=<SoftmaxBackward0>)

# %%
criterion = nn.CrossEntropyLoss() # this is the loss function, we use cross entropy loss as we are using softmax, we can get away with/without softmax
optimizer = optim.Adam(model.parameters(), lr=0.001) #smaller lr takes longer to converge, adam is adaptive momentum optimizer

# %%
epochs = 1
for e in range(epochs):
    for i, (images, labels) in enumerate(iter(trainloader)):
        optimizer.zero_grad()  # to clean the gradient else it will accumulate the gradients
                                    # pytorch by default saves the gradients using the autograd,so it can do backpropagation quickly, but for each step we 
                                    # want fresh gradients for each iter, so we need to clean the gradients
        
        output = model.forward(images)
        loss = criterion(output, labels) 
        loss.backward()
        optimizer.step()

# %%
images, labels = next(dataiter)
t_img = images[7]
ps = model(t_img)

# %%
img.shape
# Out:
# torch.Size([1, 28, 28])

# %%
ps
# Out:
# tensor([[1.3064e-24, 9.9999e-01, 2.0664e-10, 7.7127e-12, 1.0685e-14, 6.2709e-10,
#          2.3192e-09, 1.3449e-12, 5.0266e-06, 3.6914e-13]],
#        grad_fn=<SoftmaxBackward0>)

# %%
view_classify(t_img, ps)

# %%
# training the model, you need to create this pretty much once adn you can use this over and over again the core is the 
# zero_grad() to the optimizer.step()
epochs = 3
print_every = 40

for e in range(epochs):
    running_loss = 0
    print(f"Epoch: {e+1}/{epochs}")

    for i, (images, labels) in enumerate(iter(trainloader)):    # tuple unpacking as we have both image and labels from the dataloader

        # Flatten MNIST images into a 784 long vector
        # images.resize_(images.size()[0], 784) # no need since we defined it in the forward pass
        
        optimizer.zero_grad()       # to clean the gradient else it will accumulate the gradients
                                    # pytorch by default saves the gradients using the autograd,so it can do backpropagation quickly, but for each step we 
                                    # want fresh gradients for each iter, so we need to clean the gradients
        
        output = model.forward(images)   # 1) Forward pass   # you can also use model(images)
        loss = criterion(output, labels) # 2) Compute loss
        loss.backward()                  # 3) Backward pass
        optimizer.step()                 # 4) Update model
        
        running_loss += loss.item()
        
        if i % print_every == 0:
            print(f"\tIteration: {i}\t Loss: {running_loss/print_every:.4f}")
            running_loss = 0
# Out:
# Epoch: 1/3
# 	Iteration: 0	 Loss: 0.0379
# 	Iteration: 40	 Loss: 1.5604
# 	Iteration: 80	 Loss: 1.5678
# 	Iteration: 120	 Loss: 1.5652
# 	Iteration: 160	 Loss: 1.5335
# 	Iteration: 200	 Loss: 1.5364
# 	Iteration: 240	 Loss: 1.5459
# 	Iteration: 280	 Loss: 1.5519
# 	Iteration: 320	 Loss: 1.5413
# 	Iteration: 360	 Loss: 1.5476
# 	Iteration: 400	 Loss: 1.5567
# 	Iteration: 440	 Loss: 1.5494
# 	Iteration: 480	 Loss: 1.5350
# 	Iteration: 520	 Loss: 1.5626
# 	Iteration: 560	 Loss: 1.5400
# 	Iteration: 600	 Loss: 1.5246
# 	Iteration: 640	 Loss: 1.5428
# 	Iteration: 680	 Loss: 1.5387
# 	Iteration: 720	 Loss: 1.5476
# 	Iteration: 760	 Loss: 1.5486
# 	Iteration: 800	 Loss: 1.5588
# 	Iteration: 840	 Loss: 1.5304
# 	Iteration: 880	 Loss: 1.5486
# 	Iteration: 920	 Loss: 1.5553
# 	Iteration: 960	 Loss: 1.5553
# 	Iteration: 1000	 Loss: 1.5204
# 	Iteration: 1040	 Loss: 1.5331
# 	Iteration: 1080	 Loss: 1.5387
# 	Iteration: 1120	 Loss: 1.5421
# 	Iteration: 1160	 Loss: 1.5420
# 	Iteration: 1200	 Loss: 1.5500
# 	Iteration: 1240	 Loss: 1.5390
# 	Iteration: 1280	 Loss: 1.5496
# 	Iteration: 1320	 Loss: 1.5372
# 	Iteration: 1360	 Loss: 1.5557
# 	Iteration: 1400	 Loss: 1.5388
# 	Iteration: 1440	 Loss: 1.5411
# 	Iteration: 1480	 Loss: 1.5311
# 	Iteration: 1520	 Loss: 1.5279
# 	Iteration: 1560	 Loss: 1.5421
# 	Iteration: 1600	 Loss: 1.5273
# 	Iteration: 1640	 Loss: 1.5445
# 	Iteration: 1680	 Loss: 1.5334
# 	Iteration: 1720	 Loss: 1.5526
# 	Iteration: 1760	 Loss: 1.5362
# 	Iteration: 1800	 Loss: 1.5614
# 	Iteration: 1840	 Loss: 1.5450
# 	Iteration: 1880	 Loss: 1.5338
# 	Iteration: 1920	 Loss: 1.5324
# 	Iteration: 1960	 Loss: 1.5409
# 	Iteration: 2000	 Loss: 1.5385
# 	Iteration: 2040	 Loss: 1.5271
# 	Iteration: 2080	 Loss: 1.5427
# 	Iteration: 2120	 Loss: 1.5397
# 	Iteration: 2160	 Loss: 1.5390
# 	Iteration: 2200	 Loss: 1.5388
# 	Iteration: 2240	 Loss: 1.5509
# 	Iteration: 2280	 Loss: 1.5391
# 	Iteration: 2320	 Loss: 1.5475
# 	Iteration: 2360	 Loss: 1.5421
# 	Iteration: 2400	 Loss: 1.5466
# 	Iteration: 2440	 Loss: 1.5533
# 	Iteration: 2480	 Loss: 1.5605
# 	Iteration: 2520	 Loss: 1.5462
# 	Iteration: 2560	 Loss: 1.5153
# 	Iteration: 2600	 Loss: 1.5386
# 	Iteration: 2640	 Loss: 1.5311
# 	Iteration: 2680	 Loss: 1.5349
# 	Iteration: 2720	 Loss: 1.5411
# 	Iteration: 2760	 Loss: 1.5273
# 	Iteration: 2800	 Loss: 1.5352
# 	Iteration: 2840	 Loss: 1.5462
# 	Iteration: 2880	 Loss: 1.5430
# 	Iteration: 2920	 Loss: 1.5296
# 	Iteration: 2960	 Loss: 1.5489
# 	Iteration: 3000	 Loss: 1.5383
# 	Iteration: 3040	 Loss: 1.5329
# 	Iteration: 3080	 Loss: 1.5208
# 	Iteration: 3120	 Loss: 1.5574
# 	Iteration: 3160	 Loss: 1.5269
# 	Iteration: 3200	 Loss: 1.5231
# 	Iteration: 3240	 Loss: 1.5450
# 	Iteration: 3280	 Loss: 1.5400
# 	Iteration: 3320	 Loss: 1.5433
# 	Iteration: 3360	 Loss: 1.5237
# 	Iteration: 3400	 Loss: 1.5471
# 	Iteration: 3440	 Loss: 1.5578
# 	Iteration: 3480	 Loss: 1.5321
# 	Iteration: 3520	 Loss: 1.5251
# 	Iteration: 3560	 Loss: 1.5318
# 	Iteration: 3600	 Loss: 1.5302
# 	Iteration: 3640	 Loss: 1.5250
# 	Iteration: 3680	 Loss: 1.5543
# 	Iteration: 3720	 Loss: 1.5165
# Epoch: 2/3
# 	Iteration: 0	 Loss: 0.0366
# 	Iteration: 40	 Loss: 1.5436
# 	Iteration: 80	 Loss: 1.5240
# 	Iteration: 120	 Loss: 1.5459
# 	Iteration: 160	 Loss: 1.5182
# 	Iteration: 200	 Loss: 1.5195
# 	Iteration: 240	 Loss: 1.5522
# 	Iteration: 280	 Loss: 1.5239
# 	Iteration: 320	 Loss: 1.5301
# 	Iteration: 360	 Loss: 1.5277
# 	Iteration: 400	 Loss: 1.5356
# 	Iteration: 440	 Loss: 1.5656
# 	Iteration: 480	 Loss: 1.5207
# 	Iteration: 520	 Loss: 1.5139
# 	Iteration: 560	 Loss: 1.5415
# 	Iteration: 600	 Loss: 1.5495
# 	Iteration: 640	 Loss: 1.5419
# 	Iteration: 680	 Loss: 1.5394
# 	Iteration: 720	 Loss: 1.5166
# 	Iteration: 760	 Loss: 1.5218
# 	Iteration: 800	 Loss: 1.5242
# 	Iteration: 840	 Loss: 1.5233
# 	Iteration: 880	 Loss: 1.5213
# 	Iteration: 920	 Loss: 1.5219
# 	Iteration: 960	 Loss: 1.5528
# 	Iteration: 1000	 Loss: 1.5299
# 	Iteration: 1040	 Loss: 1.5377
# 	Iteration: 1080	 Loss: 1.5341
# 	Iteration: 1120	 Loss: 1.5257
# 	Iteration: 1160	 Loss: 1.5282
# 	Iteration: 1200	 Loss: 1.5306
# 	Iteration: 1240	 Loss: 1.5295
# 	Iteration: 1280	 Loss: 1.5278
# 	Iteration: 1320	 Loss: 1.5399
# 	Iteration: 1360	 Loss: 1.5263
# 	Iteration: 1400	 Loss: 1.5290
# 	Iteration: 1440	 Loss: 1.5085
# 	Iteration: 1480	 Loss: 1.5251
# 	Iteration: 1520	 Loss: 1.5323
# 	Iteration: 1560	 Loss: 1.5265
# 	Iteration: 1600	 Loss: 1.5349
# 	Iteration: 1640	 Loss: 1.5136
# 	Iteration: 1680	 Loss: 1.5522
# 	Iteration: 1720	 Loss: 1.5307
# 	Iteration: 1760	 Loss: 1.5073
# 	Iteration: 1800	 Loss: 1.5192
# 	Iteration: 1840	 Loss: 1.5261
# 	Iteration: 1880	 Loss: 1.5094
# 	Iteration: 1920	 Loss: 1.5224
# 	Iteration: 1960	 Loss: 1.5178
# 	Iteration: 2000	 Loss: 1.5138
# 	Iteration: 2040	 Loss: 1.5184
# 	Iteration: 2080	 Loss: 1.5331
# 	Iteration: 2120	 Loss: 1.5427
# 	Iteration: 2160	 Loss: 1.5223
# 	Iteration: 2200	 Loss: 1.5411
# 	Iteration: 2240	 Loss: 1.5381
# 	Iteration: 2280	 Loss: 1.5203
# 	Iteration: 2320	 Loss: 1.5212
# 	Iteration: 2360	 Loss: 1.5316
# 	Iteration: 2400	 Loss: 1.5232
# 	Iteration: 2440	 Loss: 1.5059
# 	Iteration: 2480	 Loss: 1.5334
# 	Iteration: 2520	 Loss: 1.5274
# 	Iteration: 2560	 Loss: 1.5371
# 	Iteration: 2600	 Loss: 1.5401
# 	Iteration: 2640	 Loss: 1.5155
# 	Iteration: 2680	 Loss: 1.5205
# 	Iteration: 2720	 Loss: 1.5272
# 	Iteration: 2760	 Loss: 1.5297
# 	Iteration: 2800	 Loss: 1.5260
# 	Iteration: 2840	 Loss: 1.5207
# 	Iteration: 2880	 Loss: 1.5235
# 	Iteration: 2920	 Loss: 1.5305
# 	Iteration: 2960	 Loss: 1.5256
# 	Iteration: 3000	 Loss: 1.5197
# 	Iteration: 3040	 Loss: 1.5164
# 	Iteration: 3080	 Loss: 1.5360
# 	Iteration: 3120	 Loss: 1.5370
# 	Iteration: 3160	 Loss: 1.5365
# 	Iteration: 3200	 Loss: 1.5317
# 	Iteration: 3240	 Loss: 1.5194
# 	Iteration: 3280	 Loss: 1.5101
# 	Iteration: 3320	 Loss: 1.5472
# 	Iteration: 3360	 Loss: 1.5253
# 	Iteration: 3400	 Loss: 1.5312
# 	Iteration: 3440	 Loss: 1.5209
# 	Iteration: 3480	 Loss: 1.5308
# 	Iteration: 3520	 Loss: 1.5098
# 	Iteration: 3560	 Loss: 1.5113
# 	Iteration: 3600	 Loss: 1.5247
# 	Iteration: 3640	 Loss: 1.5194
# 	Iteration: 3680	 Loss: 1.5156
# 	Iteration: 3720	 Loss: 1.5323
# Epoch: 3/3
# 	Iteration: 0	 Loss: 0.0365
# 	Iteration: 40	 Loss: 1.5297
# 	Iteration: 80	 Loss: 1.5170
# 	Iteration: 120	 Loss: 1.5212
# 	Iteration: 160	 Loss: 1.5248
# 	Iteration: 200	 Loss: 1.5481
# 	Iteration: 240	 Loss: 1.5221
# 	Iteration: 280	 Loss: 1.5402
# 	Iteration: 320	 Loss: 1.5181
# 	Iteration: 360	 Loss: 1.5629
# 	Iteration: 400	 Loss: 1.5091
# 	Iteration: 440	 Loss: 1.5194
# 	Iteration: 480	 Loss: 1.4974
# 	Iteration: 520	 Loss: 1.5114
# 	Iteration: 560	 Loss: 1.5234
# 	Iteration: 600	 Loss: 1.5179
# 	Iteration: 640	 Loss: 1.5113
# 	Iteration: 680	 Loss: 1.5186
# 	Iteration: 720	 Loss: 1.5200
# 	Iteration: 760	 Loss: 1.5256
# 	Iteration: 800	 Loss: 1.5307
# 	Iteration: 840	 Loss: 1.5247
# 	Iteration: 880	 Loss: 1.5290
# 	Iteration: 920	 Loss: 1.5369
# 	Iteration: 960	 Loss: 1.5281
# 	Iteration: 1000	 Loss: 1.5378
# 	Iteration: 1040	 Loss: 1.5242
# 	Iteration: 1080	 Loss: 1.5251
# 	Iteration: 1120	 Loss: 1.5201
# 	Iteration: 1160	 Loss: 1.5194
# 	Iteration: 1200	 Loss: 1.5387
# 	Iteration: 1240	 Loss: 1.5111
# 	Iteration: 1280	 Loss: 1.5398
# 	Iteration: 1320	 Loss: 1.5255
# 	Iteration: 1360	 Loss: 1.5140
# 	Iteration: 1400	 Loss: 1.5275
# 	Iteration: 1440	 Loss: 1.5122
# 	Iteration: 1480	 Loss: 1.5046
# 	Iteration: 1520	 Loss: 1.5301
# 	Iteration: 1560	 Loss: 1.5145
# 	Iteration: 1600	 Loss: 1.5226
# 	Iteration: 1640	 Loss: 1.5275
# 	Iteration: 1680	 Loss: 1.5110
# 	Iteration: 1720	 Loss: 1.5151
# 	Iteration: 1760	 Loss: 1.5217
# 	Iteration: 1800	 Loss: 1.5307
# 	Iteration: 1840	 Loss: 1.5210
# 	Iteration: 1880	 Loss: 1.5441
# 	Iteration: 1920	 Loss: 1.5340
# 	Iteration: 1960	 Loss: 1.5380
# 	Iteration: 2000	 Loss: 1.5219
# 	Iteration: 2040	 Loss: 1.5195
# 	Iteration: 2080	 Loss: 1.5519
# 	Iteration: 2120	 Loss: 1.5139
# 	Iteration: 2160	 Loss: 1.5272
# 	Iteration: 2200	 Loss: 1.5226
# 	Iteration: 2240	 Loss: 1.5233
# 	Iteration: 2280	 Loss: 1.5172
# 	Iteration: 2320	 Loss: 1.5175
# 	Iteration: 2360	 Loss: 1.5118
# 	Iteration: 2400	 Loss: 1.5254
# 	Iteration: 2440	 Loss: 1.5186
# 	Iteration: 2480	 Loss: 1.5113
# 	Iteration: 2520	 Loss: 1.5097
# 	Iteration: 2560	 Loss: 1.5263
# 	Iteration: 2600	 Loss: 1.5227
# 	Iteration: 2640	 Loss: 1.5206
# 	Iteration: 2680	 Loss: 1.5057
# 	Iteration: 2720	 Loss: 1.5259
# 	Iteration: 2760	 Loss: 1.5118
# 	Iteration: 2800	 Loss: 1.5111
# 	Iteration: 2840	 Loss: 1.5036
# 	Iteration: 2880	 Loss: 1.5295
# 	Iteration: 2920	 Loss: 1.5313
# 	Iteration: 2960	 Loss: 1.5178
# 	Iteration: 3000	 Loss: 1.5359
# 	Iteration: 3040	 Loss: 1.5238
# 	Iteration: 3080	 Loss: 1.5306
# 	Iteration: 3120	 Loss: 1.5326
# 	Iteration: 3160	 Loss: 1.5061
# 	Iteration: 3200	 Loss: 1.5098
# 	Iteration: 3240	 Loss: 1.5209
# 	Iteration: 3280	 Loss: 1.5155
# 	Iteration: 3320	 Loss: 1.5116
# 	Iteration: 3360	 Loss: 1.5260
# 	Iteration: 3400	 Loss: 1.5292
# 	Iteration: 3440	 Loss: 1.5178
# 	Iteration: 3480	 Loss: 1.5162
# 	Iteration: 3520	 Loss: 1.5072
# 	Iteration: 3560	 Loss: 1.5061
# 	Iteration: 3600	 Loss: 1.5121
# 	Iteration: 3640	 Loss: 1.5208
# 	Iteration: 3680	 Loss: 1.5087
# 	Iteration: 3720	 Loss: 1.5193
